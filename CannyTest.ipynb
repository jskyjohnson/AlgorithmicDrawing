# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
from matplotlib.pyplot import figure
print(cv2.__version__)
# Out:
# 4.1.1

# %%
img = cv2.imread('cat.jpg')
plt.imshow(img)
#cv2.imshow('image',img)

# %%
img = cv2.imread('cat.jpg',0)
edges = cv2.Canny(img,100,400,500, 3, L2gradient=True)
figure(figsize=(8,6))



plt.subplot(121)
plt.imshow(img,cmap = 'gray')
plt.title('Original Image'), plt.xticks([]), plt.yticks([])

plt.subplot(122)
plt.imshow(edges,cmap = 'gray')
plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
plt.show()

# %%
import ipywidgets as widgets
from ipywidgets import interact, interact_manual

from IPython.display import display

# %%
def f(x, y, z, a, t):
    edges = cv2.Canny(img,x,y,z, a, L2gradient=t) #100, 400, 500, 3, True
    plt.subplot(122)
    plt.imshow(edges,cmap = 'gray')
    plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
    plt.show()

# %% [markdown]
# # Canny test

# %%
#Canny version 1

interact(f, x=widgets.IntSlider(min=0, max=1000, step=20, value=10),
        y=widgets.IntSlider(min=0, max=1000, step=20, value=10),
        z=widgets.IntSlider(min=0, max=1000, step=20, value=10),
        a=widgets.IntSlider(min=3, max=7, step=2, value=3),
        t=widgets.Checkbox(value=False,description='Check me',disabled=False));

# %%
x=widgets.IntSlider(min=0, max=1000, step=20, value=10)
y=widgets.IntSlider(min=0, max=1000, step=20, value=10)
z=widgets.IntSlider(min=0, max=1000, step=20, value=10)
a=widgets.IntSlider(min=3, max=7, step=2, value=3)
t=widgets.Checkbox(value=False,description='Check me',disabled=False)

ui = widgets.HBox([x, y, z, a, t])

out = widgets.interactive_output(f, {'x': x, 'y': y, 'z': z, 'a':a, 't':t})

display(ui, out)
# Out:
# HBox(children=(IntSlider(value=10, max=1000, step=20), IntSlider(value=10, max=1000, step=20), IntSlider(value…
# Output()

# %% [markdown]
# # Laplacian

# %%
def g(x):
    #edges = cv2.Canny(img,x,y,z, a, L2gradient=t) #100, 400, 500, 3, True
    edge = cv2.Laplacian(img, x)
    plt.subplot(122)
    plt.imshow(edges,cmap = 'gray')
    plt.title('Edge Image'), plt.xticks([]), plt.yticks([])
    plt.show()

x=widgets.IntSlider(min=0, max=10, step=1, value=5)
ui = widgets.HBox([x])

out = widgets.interactive_output(g, {'x': x})
    
display(ui, out)
# Out:
# HBox(children=(IntSlider(value=5, max=10),))
# Output()
